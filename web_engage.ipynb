# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importing the data

# %%
df = pd.read_csv("data-export.csv")
df
# Out:
#              # ----------------------------------------  \
# 0     Session primary channel group (Default channel...
# 1                                                Direct
# 2                                        Organic Social
# 3                                                Direct
# 4                                        Organic Social
# ...                                                 ...
# 3178                                         Unassigned
# 3179                                         Unassigned
# 3180                                         Unassigned
# 3181                                         Unassigned
# 3182                                         Unassigned
#
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0     Date + hour (YYYYMMDDHH)      Users   Sessions  Engaged sessions
# 1                   2024041623        237        300               144
# 2                   2024041719        208        267               132
# ...

# %% [markdown]
# reseting the header and the index of the data

# %%
head_new= df.iloc[0]
df=df[1:]
df.columns = head_new
df.reset_index(drop=True ,inplace=True)

# %%
df
# Out:
# 0    Session primary channel group (Default channel group)  \
# 0                                                Direct
# 1                                        Organic Social
# 2                                                Direct
# 3                                        Organic Social
# 4                                        Organic Social
# ...                                                 ...
# 3177                                         Unassigned
# 3178                                         Unassigned
# 3179                                         Unassigned
# 3180                                         Unassigned
# 3181                                         Unassigned
#
# 0    Date + hour (YYYYMMDDHH) Users Sessions Engaged sessions  \
# 0                  2024041623   237      300              144
# 1                  2024041719   208      267              132
# 2                  2024041723   188      233              115
# ...

# %% [markdown]
# Data Understanding

# %%
df.sample(10)
# Out:
# 0    Session primary channel group (Default channel group)  \
# 1785                                             Direct
# 718                                      Organic Search
# 2591                                           Referral
# 593                                      Organic Search
# 2975                                         Unassigned
# 2415                                     Organic Search
# 2219                                     Organic Search
# 824                                      Organic Search
# 223                                      Organic Social
# 2853                                      Organic Video
#
# 0    Date + hour (YYYYMMDDHH) Users Sessions Engaged sessions  \
# 1785               2024041413    36       47               19
# 718                2024042312    62       71               40
# 2591               2024041402    14       18               11
# 593                2024041923    66       75               48
# ...

# %%
df.describe()
# Out:
# 0      Session primary channel group (Default channel group)  \
# count                                                3182
# unique                                                  7
# top                                                Direct
# freq                                                  672
#
# 0      Date + hour (YYYYMMDDHH) Users Sessions Engaged sessions  \
# count                      3182  3182     3182             3182
# unique                      672   147      180              103
# top                  2024041719     1        1                0
# freq                          6   335      340              393
#
# 0      Average engagement time per session Engaged sessions per user  \
# count                                 3182                      3182
# unique                                2823                       808
# top                                      0                         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 10 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Session primary channel group (Default channel group)  3182 non-null   object
#  1   Date + hour (YYYYMMDDHH)                               3182 non-null   object
#  2   Users                                                  3182 non-null   object
#  3   Sessions                                               3182 non-null   object
#  4   Engaged sessions                                       3182 non-null   object
#  5   Average engagement time per session                    3182 non-null   object
#  6   Engaged sessions per user                              3182 non-null   object
#  7   Events per session                                     3182 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# 0
# Session primary channel group (Default channel group)    0
# Date + hour (YYYYMMDDHH)                                 0
# Users                                                    0
# Sessions                                                 0
# Engaged sessions                                         0
# Average engagement time per session                      0
# Engaged sessions per user                                0
# Events per session                                       0
# Engagement rate                                          0
# Event count                                              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(5)
# Out:
# 0 Session primary channel group (Default channel group)  \
# 0                                             Direct
# 1                                     Organic Social
# 2                                             Direct
# 3                                     Organic Social
# 4                                     Organic Social
#
# 0 Date + hour (YYYYMMDDHH) Users Sessions Engaged sessions  \
# 0               2024041623   237      300              144
# 1               2024041719   208      267              132
# 2               2024041723   188      233              115
# 3               2024041718   187      256              125
# 4               2024041720   175      221              112
#
# 0 Average engagement time per session Engaged sessions per user  \
# 0                  47.526666666666700        0.6075949367088610
# 1                   32.09737827715360        0.6346153846153850
# 2                   39.93991416309010        0.6117021276595740
# ...

# %%
df.tail(5)
# Out:
# 0    Session primary channel group (Default channel group)  \
# 3177                                         Unassigned
# 3178                                         Unassigned
# 3179                                         Unassigned
# 3180                                         Unassigned
# 3181                                         Unassigned
#
# 0    Date + hour (YYYYMMDDHH) Users Sessions Engaged sessions  \
# 3177               2024042806     0        1                0
# 3178               2024043005     0        1                0
# 3179               2024043006     0        1                0
# 3180               2024050105     0        1                0
# 3181               2024050307     0        1                0
#
# 0    Average engagement time per session Engaged sessions per user  \
# 3177                                   0                         0
# 3178                                   0                         0
# ...

# %% [markdown]
# Data Prepration

# %% [markdown]
#     Changing df['Date + hour (YYYYMMDDHH)'] to proper time format

# %%
df['Date + hour (YYYYMMDDHH)'] = pd.to_datetime(df['Date + hour (YYYYMMDDHH)'] , format='%Y%m%d%H' )
df['Date + hour (YYYYMMDDHH)']
# Out:
# 0      2024-04-16 23:00:00
# 1      2024-04-17 19:00:00
# 2      2024-04-17 23:00:00
# 3      2024-04-17 18:00:00
# 4      2024-04-17 20:00:00
#                ...
# 3177   2024-04-28 06:00:00
# 3178   2024-04-30 05:00:00
# 3179   2024-04-30 06:00:00
# 3180   2024-05-01 05:00:00
# 3181   2024-05-03 07:00:00
# Name: Date + hour (YYYYMMDDHH), Length: 3182, dtype: datetime64[ns]

# %%
df['Users'] = df.Users.astype(int)

# %%
df['Sessions'] = df.Sessions.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 10 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Session primary channel group (Default channel group)  3182 non-null   object
#  1   Date + hour (YYYYMMDDHH)                               3182 non-null   datetime64[ns]
#  2   Users                                                  3182 non-null   int64
#  3   Sessions                                               3182 non-null   int64
#  4   Engaged sessions                                       3182 non-null   object
#  5   Average engagement time per session                    3182 non-null   object
#  6   Engaged sessions per user                              3182 non-null   object
#  7   Events per session                                     3182 non-null   object
# ...

# %%
df
# Out:
# 0    Session primary channel group (Default channel group)  \
# 0                                                Direct
# 1                                        Organic Social
# 2                                                Direct
# 3                                        Organic Social
# 4                                        Organic Social
# ...                                                 ...
# 3177                                         Unassigned
# 3178                                         Unassigned
# 3179                                         Unassigned
# 3180                                         Unassigned
# 3181                                         Unassigned
#
# 0    Date + hour (YYYYMMDDHH)  Users  Sessions Engaged sessions  \
# 0         2024-04-16 23:00:00    237       300              144
# 1         2024-04-17 19:00:00    208       267              132
# 2         2024-04-17 23:00:00    188       233              115
# ...

# %%
df['Engaged sessions'] =df['Engaged sessions'].astype(int)
df['Engaged sessions']
# Out:
# 0       144
# 1       132
# 2       115
# 3       125
# 4       112
#        ...
# 3177      0
# 3178      0
# 3179      0
# 3180      0
# 3181      0
# Name: Engaged sessions, Length: 3182, dtype: int64

# %% [markdown]
# Analysing the users and the sessions

# %%
plt.figure(figsize=(17,5))
plt.plot(df['Users'], df['Sessions'], color='g')
plt.title("plot betweeen users and session")
plt.xlabel("Users") 
plt.ylabel("Session")
plt.grid()

# %% [markdown]
# INSIGHT:
#
# The graph shows that as the number of users increases, the number of sessions also increases, indicating a positive correlation. However, there are fluctuations in session numbers, especially after 100 users, suggesting varying engagement levels. After 150 users, the trend becomes smoother, meaning sessions stabilize as more users join.

# %% [markdown]
# Converting relevant columns to numeric for engagement analysis

# %%
df['Engaged sessions'] = pd.to_numeric(df['Engaged sessions'])
df['Average engagement time per session'] = pd.to_numeric(df['Average engagement time per session'])
df['Engaged sessions per user'] = pd.to_numeric(df['Engaged sessions per user'])
df['Events per session'] = pd.to_numeric(df['Events per session'])
df['Engagement rate'] = pd.to_numeric(df['Engagement rate'])
df['Event count'] = pd.to_numeric(df['Event count'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 10 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Session primary channel group (Default channel group)  3182 non-null   object
#  1   Date + hour (YYYYMMDDHH)                               3182 non-null   datetime64[ns]
#  2   Users                                                  3182 non-null   int64
#  3   Sessions                                               3182 non-null   int64
#  4   Engaged sessions                                       3182 non-null   int64
#  5   Average engagement time per session                    3182 non-null   float64
#  6   Engaged sessions per user                              3182 non-null   float64
#  7   Events per session                                     3182 non-null   float64
# ...

# %% [markdown]
# Analysing the correlation betewen all the variables

# %%
sns.pairplot(data=df )

# %% [markdown]
# Inference:
#
# Engagement Time vs. Events per Session → Short sessions can have many or few events, but longer sessions usually have fewer events.
#
# Engagement Time vs. Engagement Rate → When users spend very little time, engagement rates fluctuate, but with more time, engagement becomes stable and higher.
#
# Engaged Sessions per User vs. Events per Session → Most users don’t engage much, with only a few having both high session counts and many events.
#
# Engaged Sessions per User vs. Engagement Rate → The more engaged sessions a user has, the higher their engagement rate tends to be.

# %% [markdown]
# Now, moving on to user engagement analysis

# %%
# group data by date and calculate mean for engagement metrics
engagement_metrics = df.groupby(df['Date + hour (YYYYMMDDHH)']).agg({
    'Average engagement time per session': 'mean',
    'Engaged sessions per user': 'mean',
    'Events per session': 'mean',
    'Engagement rate': 'mean'
})

# plotting engagement metrics
fig, ax = plt.subplots(4, 1, figsize=(14, 20), sharex=True)

ax[0].plot(engagement_metrics.index, engagement_metrics['Average engagement time per session'], label='Avg Engagement Time', color='green')
ax[0].set_title('Average Engagement Time per Session')
ax[0].set_ylabel('Seconds')

ax[1].plot(engagement_metrics.index, engagement_metrics['Engaged sessions per user'], label='Engaged Sessions/User', color='blue')
ax[1].set_title('Engaged Sessions per User')
ax[1].set_ylabel('Ratio')

ax[2].plot(engagement_metrics.index, engagement_metrics['Events per session'], label='Events per Session', color='yellow')
ax[2].set_title('Events per Session')
ax[2].set_ylabel('Count')

ax[3].plot(engagement_metrics.index, engagement_metrics['Engagement rate'], label='Engagement Rate', color='purple')
ax[3].set_title('Engagement Rate')
ax[3].set_ylabel('Rate')
ax[3].set_xlabel('Date and Hour')

for a in ax:
    a.legend()
    a.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# INFERENCE:
#
# Engagement Time: Users spend different amounts of time per session, with peaks likely due to new content or events.
#
# Sessions per User: The number of engaged sessions per user fluctuates but remains strong, suggesting relevant content drives interaction.
#
# Events per Session: Users consistently interact with site features, with occasional peaks indicating more engaging or interactive content.
#
# Engagement Rate: The percentage of engaged sessions varies, influenced by content quality and how users are acquired.

# %%
df
# Out:
# 0    Session primary channel group (Default channel group)  \
# 0                                                Direct
# 1                                        Organic Social
# 2                                                Direct
# 3                                        Organic Social
# 4                                        Organic Social
# ...                                                 ...
# 3177                                         Unassigned
# 3178                                         Unassigned
# 3179                                         Unassigned
# 3180                                         Unassigned
# 3181                                         Unassigned
#
# 0    Date + hour (YYYYMMDDHH)  Users  Sessions  Engaged sessions  \
# 0         2024-04-16 23:00:00    237       300               144
# 1         2024-04-17 19:00:00    208       267               132
# 2         2024-04-17 23:00:00    188       233               115
# ...

# %% [markdown]
# now doing some more CHANNEL PERFORMANCE ANALYSIS

# %%
# group data by channel and aggregate necessary metrics
channel_performance = df.groupby('Session primary channel group (Default channel group)').agg({
    'Users': 'sum',
    'Sessions': 'sum',
    'Engaged sessions': 'sum',
    'Engagement rate': 'mean',
    'Events per session': 'mean'
})

# normalize engagement rate and events per session for comparison
channel_performance['Normalized Engagement Rate'] = channel_performance['Engagement rate'] / channel_performance['Engagement rate'].max()
channel_performance['Normalized Events per Session'] = channel_performance['Events per session'] / channel_performance['Events per session'].max()

# plotting channel performance metrics
fig, ax = plt.subplots(3, 1, figsize=(12, 18))

# users and sessions by channel
ax[0].bar(channel_performance.index, channel_performance['Users'], label='Users', alpha=0.8)
ax[0].bar(channel_performance.index, channel_performance['Sessions'], label='Sessions', alpha=0.6)
ax[0].set_title('Users and Sessions by Channel')
ax[0].set_ylabel('Count')
ax[0].legend()

# normalized engagement rate by channel
ax[1].bar(channel_performance.index, channel_performance['Normalized Engagement Rate'], color='orange')
ax[1].set_title('Normalized Engagement Rate by Channel')
ax[1].set_ylabel('Normalized Rate')

# normalized events per session by channel
ax[2].bar(channel_performance.index, channel_performance['Normalized Events per Session'], color='green')
ax[2].set_title('Normalized Events per Session by Channel')
ax[2].set_ylabel('Normalized Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# The data reveals key differences in how channels perform. Organic Search drives high traffic but with lower engagement, suggesting a focus on quantity over quality. On the other hand, Referral and Organic Video generate fewer visits but higher engagement, indicating strong user interest. These insights can help refine marketing strategies to balance traffic volume with meaningful interactions.

# %% [markdown]
# Overall Summary:
#
#
# Session Analysis → Helps track how many visitors come to the site and when.
# User Engagement Analysis → Shows how actively users interact with the site.
# Channel Performance → Tells which traffic sources (social media, ads, search, etc.) bring the most engaged users.
